# %%
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing dataset
dataset = pd.read_csv('ovarian_cancer2.csv')
dataset[0:10]
# Out:
#           ID  days_to_tumor_recurrence  recurrence_status  days_to_death  \
# 0  GSM432220                      1650                  0           1650
# 1  GSM432221                        30                  1             30
# 2  GSM432222                       720                  0            720
# 3  GSM432223                       450                  1            780
# 4  GSM432224                       510                  1            990
# 5  GSM432225                      1110                  0           1110
# 6  GSM432226                       210                  1            600
# 7  GSM432227                      1380                  1           1410
# 8  GSM432228                      1800                  0           1800
# 9  GSM432229                       540                  1           1710
#
#    vital_status    CXCL12 summarystage  tumorstage  group
# 0             0  1.305942         late         3.0      1
# ...
